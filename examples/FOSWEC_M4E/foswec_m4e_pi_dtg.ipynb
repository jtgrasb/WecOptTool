# %%
import FOSWEC_M4E_inputs
from foswec_m4e_base import FOSWECM4EStudyBase

study = FOSWECM4EStudyBase(
    m4e_inputs_module=FOSWEC_M4E_inputs,
    wavefreq=1/5,
    nfreq=10,
    amplitude=0.25,
)

study.load_or_run_bem(overwrite=False)
study.setup_m4e_reduction()

results = study.run_standard_controller_study()
# Out:
# INFO:capytaine.io.meshio:Stored 2772 triangle faces as quadrilaterals
# INFO:capytaine.bodies.bodies:New floating body: FloatingBody(mesh=Mesh(..., name="mesh_from_meshio_0"), lid_mesh=None, dofs={}, center_of_mass=[ 0.   0.  -0.8], name="platform").
# INFO:capytaine.bodies.bodies:The rotation dof Roll has been initialized around the point: FloatingBody(..., name="platform").center_of_mass = [ 0.   0.  -0.8]
# INFO:capytaine.bodies.bodies:The rotation dof Pitch has been initialized around the point: FloatingBody(..., name="platform").center_of_mass = [ 0.   0.  -0.8]
# INFO:capytaine.bodies.bodies:The rotation dof Yaw has been initialized around the point: FloatingBody(..., name="platform").center_of_mass = [ 0.   0.  -0.8]
# INFO:capytaine.bodies.bodies:Clipping platform with respect to Plane(normal=[0. 0. 1.], point=[0. 0. 0.])
# INFO:capytaine.io.meshio:Stored 348 triangle faces as quadrilaterals
# INFO:capytaine.bodies.bodies:New floating body: FloatingBody(mesh=Mesh(..., name="mesh_from_meshio_6"), lid_mesh=None, dofs={}, center_of_mass=[-0.72  0.   -0.42], name="flap1").
# INFO:capytaine.bodies.bodies:The rotation dof Roll has been initialized around the point: FloatingBody(..., name="flap1").center_of_mass = [-0.72  0.   -0.42]
# INFO:capytaine.bodies.bodies:The rotation dof Pitch has been initialized around the point: FloatingBody(..., name="flap1").center_of_mass = [-0.72  0.   -0.42]
# INFO:capytaine.bodies.bodies:The rotation dof Yaw has been initialized around the point: FloatingBody(..., name="flap1").center_of_mass = [-0.72  0.   -0.42]
# INFO:capytaine.bodies.bodies:Clipping flap1 with respect to Plane(normal=[0. 0. 1.], point=[0. 0. 0.])
# INFO:capytaine.meshes.clipper:Clipping mesh_from_meshio_6 by Plane(normal=[0. 0. 1.], point=[0. 0. 0.]): no action.
# INFO:capytaine.io.meshio:Stored 348 triangle faces as quadrilaterals
# INFO:capytaine.bodies.bodies:New floating body: FloatingBody(mesh=Mesh(..., name="mesh_from_meshio_7"), lid_mesh=None, dofs={}, center_of_mass=[ 0.72  0.   -0.42], name="flap2").
# INFO:capytaine.bodies.bodies:The rotation dof Roll has been initialized around the point: FloatingBody(..., name="flap2").center_of_mass = [ 0.72  0.   -0.42]
# INFO:capytaine.bodies.bodies:The rotation dof Pitch has been initialized around the point: FloatingBody(..., name="flap2").center_of_mass = [ 0.72  0.   -0.42]
# INFO:capytaine.bodies.bodies:The rotation dof Yaw has been initialized around the point: FloatingBody(..., name="flap2").center_of_mass = [ 0.72  0.   -0.42]
# INFO:capytaine.bodies.bodies:Clipping flap2 with respect to Plane(normal=[0. 0. 1.], point=[0. 0. 0.])
# INFO:capytaine.meshes.clipper:Clipping mesh_from_meshio_7 by Plane(normal=[0. 0. 1.], point=[0. 0. 0.]): no action.
# INFO:capytaine.bodies.bodies:New floating body: FloatingBody(mesh=CollectionOfMeshes(..., name="platform+flap1_mesh"), lid_mesh=None, dofs={"platform__Surge": ..., "platform__Sway": ..., "platform__Heave": ..., "platform__Roll": ..., "platform__Pitch": ..., "platform__Yaw": ..., "flap1__Surge": ..., "flap1__Sway": ..., "flap1__Heave": ..., "flap1__Roll": ..., "flap1__Pitch": ..., "flap1__Yaw": ...}, name="platform+flap1").
# INFO:capytaine.bodies.bodies:New floating body: FloatingBody(mesh=CollectionOfMeshes(..., name="platform+flap1+flap2_mesh"), lid_mesh=None, dofs={"platform__Surge": ..., "platform__Sway": ..., "platform__Heave": ..., "platform__Roll": ..., "platform__Pitch": ..., "platform__Yaw": ..., "flap1__Surge": ..., "flap1__Sway": ..., "flap1__Heave": ..., "flap1__Roll": ..., "flap1__Pitch": ..., "flap1__Yaw": ..., "flap2__Surge": ..., "flap2__Sway": ..., "flap2__Heave": ..., "flap2__Roll": ..., "flap2__Pitch": ..., "flap2__Yaw": ...}, name="platform+flap1+flap2").
# INFO:capytaine.green_functions.delhommeau:Loading tabulation from C:\Users\jtgrasb\AppData\Local\capytaine\Cache\2.3.1\tabulation_float64_scaled_nemoh3_676_100.0_372_-251.0_1001.npz
# WARNING:wecopttool.core:Using the geometric centroid as the center of gravity (COG).
# [14:42:25] WARNING  Using the geometric centroid as the center of gravity (COG).
# WARNING:wecopttool.core:Using the center of gravity (COG) as the rotation center for hydrostatics. Note that the hydrostatics do not use the axes defined by the FloatingBody degrees of freedom, and the rotation center should be set manually when using Capytaine to calculate hydrostatics about an axis other than the COG.
#            WARNING  Using the center of gravity (COG) as the rotation center for hydrostatics. Note that the
#                     hydrostatics do not use the axes defined by the FloatingBody degrees of freedom, and the
#                     rotation center should be set manually when using Capytaine to calculate hydrostatics about an
#                     axis other than the COG.
# INFO:capytaine.bodies.bodies:Clipping copy_of_platform+flap1+flap2 with respect to Plane(normal=[0. 0. 1.], point=[0. 0. 0.])
# INFO:capytaine.meshes.clipper:Clipping mesh_from_meshio_6 by Plane(normal=[0. 0. 1.], point=[0. 0. 0.]): no action.
# INFO:capytaine.meshes.clipper:Clipping mesh_from_meshio_7 by Plane(normal=[0. 0. 1.], point=[0. 0. 0.]): no action.
# WARNING:capytaine.bem.solver:Mesh resolution for 38 problems:
# The resolution of the mesh might be insufficient for omega ranging from 11.310 to 12.566.
# This warning appears when the largest panel of this mesh has radius > wavelength/8.
# [14:42:26] WARNING  Mesh resolution for 38 problems:
#                     The resolution of the mesh might be insufficient for omega ranging from 11.310 to 12.566.
#                     This warning appears when the largest panel of this mesh has radius > wavelength/8.
# Output()
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='platform__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='platform__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='platform__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='platform__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='platform__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='platform__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='flap1__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='flap1__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='flap1__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='flap1__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='flap1__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='flap1__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='flap2__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='flap2__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='flap2__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='flap2__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='flap2__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=1.257, water_depth=2.0, radiating_dof='flap2__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='platform__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='platform__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='platform__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='platform__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='platform__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='platform__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='flap1__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='flap1__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='flap1__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='flap1__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='flap1__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='flap1__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='flap2__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='flap2__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='flap2__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='flap2__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='flap2__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=2.513, water_depth=2.0, radiating_dof='flap2__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='platform__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='platform__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='platform__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='platform__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='platform__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='platform__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='flap1__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='flap1__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='flap1__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='flap1__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='flap1__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='flap1__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='flap2__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='flap2__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='flap2__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='flap2__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='flap2__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=3.770, water_depth=2.0, radiating_dof='flap2__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='platform__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='platform__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='platform__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='platform__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='platform__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='platform__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='flap1__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='flap1__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='flap1__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='flap1__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='flap1__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='flap1__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='flap2__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='flap2__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='flap2__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='flap2__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='flap2__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=5.027, water_depth=2.0, radiating_dof='flap2__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='platform__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='platform__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='platform__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='platform__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='platform__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='platform__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='flap1__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='flap1__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='flap1__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='flap1__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='flap1__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='flap1__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='flap2__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='flap2__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='flap2__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='flap2__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='flap2__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=6.283, water_depth=2.0, radiating_dof='flap2__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='platform__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='platform__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='platform__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='platform__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='platform__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='platform__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='flap1__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='flap1__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='flap1__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='flap1__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='flap1__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='flap1__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='flap2__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='flap2__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='flap2__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='flap2__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='flap2__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=7.540, water_depth=2.0, radiating_dof='flap2__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='platform__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='platform__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='platform__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='platform__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='platform__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='platform__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='flap1__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='flap1__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='flap1__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='flap1__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='flap1__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='flap1__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='flap2__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='flap2__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='flap2__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='flap2__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='flap2__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=8.796, water_depth=2.0, radiating_dof='flap2__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='platform__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='platform__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='platform__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='platform__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='platform__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='platform__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='flap1__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='flap1__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='flap1__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='flap1__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='flap1__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='flap1__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='flap2__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='flap2__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='flap2__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='flap2__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='flap2__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=10.053, water_depth=2.0, radiating_dof='flap2__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='platform__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='platform__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='platform__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='platform__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='platform__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='platform__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='flap1__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='flap1__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='flap1__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='flap1__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='flap1__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='flap1__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='flap2__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='flap2__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='flap2__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='flap2__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='flap2__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=11.310, water_depth=2.0, radiating_dof='flap2__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='platform__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='platform__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='platform__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='platform__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='platform__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='platform__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='flap1__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='flap1__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='flap1__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='flap1__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='flap1__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='flap1__Yaw', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='flap2__Surge', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='flap2__Sway', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='flap2__Heave', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='flap2__Roll', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='flap2__Pitch', rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=FloatingBody(..., name="copy_of_platform+flap1+flap2_immersed"), omega=12.566, water_depth=2.0, radiating_dof='flap2__Yaw', rho=1025.0).
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:capytaine.bem.solver:Solver timer summary:
#                     total  nb_calls   mean
# task
# Solve total       116.048       190  0.611
#   Green function   79.956       190  0.421
#   Linear solver    32.047       190  0.169
# INFO:capytaine.bodies.bodies:Clipping platform with respect to Plane(normal=[0. 0. 1.], point=[0. 0. 0.])
# INFO:capytaine.bodies.bodies:Clipping flap1 with respect to Plane(normal=[0. 0. 1.], point=[0. 0. 0.])
# INFO:capytaine.meshes.clipper:Clipping mesh_from_meshio_6 by Plane(normal=[0. 0. 1.], point=[0. 0. 0.]): no action.
# INFO:capytaine.bodies.bodies:Clipping flap2 with respect to Plane(normal=[0. 0. 1.], point=[0. 0. 0.])
# INFO:capytaine.meshes.clipper:Clipping mesh_from_meshio_7 by Plane(normal=[0. 0. 1.], point=[0. 0. 0.]): no action.
# Problem initialization finished in:		 0.002 seconds
# All branches in the graph:
# Branch 1: [1, 2]
# Branch 2: [1, 3]
# R and RD matrices calculation finished in:	 0.249 seconds
# Symbolic EOM computation finished in:		 0.089 seconds
# Compiling EOM expressions finished in:		 0.202 seconds
#
# [Info] Updating float body 1 IC from (x=0.0, z=0.0) → (x=0.0, z=-0.8) relative to Reference_frame_Origin: (x=0, z=0) .
# INFO:capytaine.bodies.bodies:New floating body: FloatingBody(mesh=Mesh(..., name="mesh_from_meshio_0"), lid_mesh=None, dofs={}, name="platform").
# INFO:capytaine.bodies.bodies:The rotation dof Roll has been initialized around the point: FloatingBody(..., name="platform").rotation_center = [ 0.   0.  -0.8]
# INFO:capytaine.bodies.bodies:The rotation dof Pitch has been initialized around the point: FloatingBody(..., name="platform").rotation_center = [ 0.   0.  -0.8]
# INFO:capytaine.bodies.bodies:The rotation dof Yaw has been initialized around the point: FloatingBody(..., name="platform").rotation_center = [ 0.   0.  -0.8]
# INFO:capytaine.bodies.bodies:New floating body: FloatingBody(mesh=Mesh(..., name="mesh_from_meshio_6"), lid_mesh=None, dofs={}, name="flap1").
# INFO:capytaine.bodies.bodies:The rotation dof Roll has been initialized around the point: FloatingBody(..., name="flap1").rotation_center = [-0.72  0.   -0.42]
# INFO:capytaine.bodies.bodies:The rotation dof Pitch has been initialized around the point: FloatingBody(..., name="flap1").rotation_center = [-0.72  0.   -0.42]
# INFO:capytaine.bodies.bodies:The rotation dof Yaw has been initialized around the point: FloatingBody(..., name="flap1").rotation_center = [-0.72  0.   -0.42]
# INFO:capytaine.bodies.bodies:New floating body: FloatingBody(mesh=Mesh(..., name="mesh_from_meshio_7"), lid_mesh=None, dofs={}, name="flap2").
# INFO:capytaine.bodies.bodies:The rotation dof Roll has been initialized around the point: FloatingBody(..., name="flap2").rotation_center = [ 0.72  0.   -0.42]
# INFO:capytaine.bodies.bodies:The rotation dof Pitch has been initialized around the point: FloatingBody(..., name="flap2").rotation_center = [ 0.72  0.   -0.42]
# INFO:capytaine.bodies.bodies:The rotation dof Yaw has been initialized around the point: FloatingBody(..., name="flap2").rotation_center = [ 0.72  0.   -0.42]
# INFO:capytaine.bodies.bodies:Clipping platform with respect to Plane(normal=[0. 0. 1.], point=[0. 0. 0.])
# [HydroAdapter] Prepared bodies:
#   [1] name='platform', CoM=[ 0.   0.  -0.8]
#   [2] name='flap1', CoM=[-0.72  0.   -0.42]
#   [3] name='flap2', CoM=[ 0.72  0.   -0.42]
# INFO:capytaine.bodies.bodies:Clipping flap1 with respect to Plane(normal=[0. 0. 1.], point=[0. 0. 0.])
# INFO:capytaine.meshes.clipper:Clipping mesh_from_meshio_6 by Plane(normal=[0. 0. 1.], point=[0. 0. 0.]): no action.
# INFO:capytaine.bodies.bodies:New floating body: FloatingBody(mesh=CollectionOfMeshes(..., name="platform+flap1_mesh"), lid_mesh=None, dofs={"platform__Surge": ..., "platform__Sway": ..., "platform__Heave": ..., "platform__Roll": ..., "platform__Pitch": ..., "platform__Yaw": ..., "flap1__Surge": ..., "flap1__Sway": ..., "flap1__Heave": ..., "flap1__Roll": ..., "flap1__Pitch": ..., "flap1__Yaw": ...}, name="platform+flap1").
# INFO:capytaine.bodies.bodies:Clipping flap2 with respect to Plane(normal=[0. 0. 1.], point=[0. 0. 0.])
# INFO:capytaine.meshes.clipper:Clipping mesh_from_meshio_7 by Plane(normal=[0. 0. 1.], point=[0. 0. 0.]): no action.
# INFO:capytaine.bodies.bodies:New floating body: FloatingBody(mesh=CollectionOfMeshes(..., name="platform+flap1+flap2_mesh"), lid_mesh=None, dofs={"platform__Surge": ..., "platform__Sway": ..., "platform__Heave": ..., "platform__Roll": ..., "platform__Pitch": ..., "platform__Yaw": ..., "flap1__Surge": ..., "flap1__Sway": ..., "flap1__Heave": ..., "flap1__Roll": ..., "flap1__Pitch": ..., "flap1__Yaw": ..., "flap2__Surge": ..., "flap2__Sway": ..., "flap2__Heave": ..., "flap2__Roll": ..., "flap2__Pitch": ..., "flap2__Yaw": ...}, name="platform+flap1+flap2").
# WARNING:wecopttool.core:Real part of impedance for 2 has negative or close to zero terms. Shifting up elements [2] to a minimum of  1e-06 N/(m/s)
# [14:44:28] WARNING  Real part of impedance for 2 has negative or close to zero terms. Shifting up elements [2] to a
#                     minimum of  1e-06 N/(m/s)
# INFO:wecopttool.core:Solving pseudo-spectral control problem for realization number 0.
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [2.12e+00, 1.00e+00, 2.46e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [2.31e+00, 1.44e-15, 2.95e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.14e+00, 5.11e-01, 7.96e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.46e+00, 2.09e-01, -7.85e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [4.08e+00, 1.23e-01, -1.70e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.24e-01, -1.16e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.30e-01, -1.17e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.30e-01, -1.17e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.30e-01, -1.17e+00]
# INFO:wecopttool.core:Optimization terminated successfully    (Exit mode 0)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.1654385212257186
#             Iterations: 9
#             Function evaluations: 13
#             Gradient evaluations: 9
# WARNING:wecopttool.core:Real part of impedance for 2 has negative or close to zero terms. Shifting up elements [2] to a minimum of  1e-06 N/(m/s)
# [14:44:41] WARNING  Real part of impedance for 2 has negative or close to zero terms. Shifting up elements [2] to a
#                     minimum of  1e-06 N/(m/s)
# INFO:wecopttool.core:Solving pseudo-spectral control problem for realization number 0.
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [1.57e+00, 1.00e+00, 4.91e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [1.54e+00, 1.51e+00, 3.72e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [2.64e+00, 1.06e-13, 3.83e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [2.77e+00, 7.29e-01, 2.70e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [2.91e+00, 5.76e-01, 9.41e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.20e+00, 3.25e-01, 2.34e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.92e+00, 2.09e-02, 5.83e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [4.09e+00, 1.54e-01, -3.05e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.73e+00, 1.06e-01, -1.11e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.76e+00, 1.28e-01, -1.17e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.30e-01, -1.17e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.30e-01, -1.17e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.30e-01, -1.17e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.30e-01, -1.17e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.30e-01, -1.17e+00]
# INFO:wecopttool.core:Optimization terminated successfully    (Exit mode 0)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.1712416819299454
#             Iterations: 15
#             Function evaluations: 21
#             Gradient evaluations: 15
# WARNING:wecopttool.core:Real part of impedance for 2 has negative or close to zero terms. Shifting up elements [2] to a minimum of  1e-06 N/(m/s)
# [14:44:49] WARNING  Real part of impedance for 2 has negative or close to zero terms. Shifting up elements [2] to a
#                     minimum of  1e-06 N/(m/s)
# INFO:wecopttool.core:Solving pseudo-spectral control problem for realization number 0.
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [1.88e+00, 1.00e+00, 3.75e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [1.88e+00, 1.49e+00, 5.09e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [2.86e+00, 2.48e+00, 2.40e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.19e+00, 2.65e+00, 3.38e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.09e+00, 1.60e+00, 1.10e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.07e+00, 1.10e+00, 4.89e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.33e+00, 1.08e+00, 3.72e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.35e+00, 1.13e+00, 3.93e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.58e+00, 6.56e-01, 1.53e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.82e+00, 3.19e-01, 4.52e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [4.71e+00, 2.48e-01, 4.76e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.34e+00, 6.20e-01, 2.19e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.71e+00, 1.63e-01, -1.07e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.37e-01, -1.17e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.29e-01, -1.18e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.30e-01, -1.18e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.30e-01, -1.18e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.30e-01, -1.18e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.30e-01, -1.18e+00]
# INFO:wecopttool.core:Optimization terminated successfully    (Exit mode 0)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.1769356867056602
#             Iterations: 19
#             Function evaluations: 31
#             Gradient evaluations: 19
# WARNING:wecopttool.core:Real part of impedance for 2 has negative or close to zero terms. Shifting up elements [2] to a minimum of  1e-06 N/(m/s)
# [14:44:59] WARNING  Real part of impedance for 2 has negative or close to zero terms. Shifting up elements [2] to a
#                     minimum of  1e-06 N/(m/s)
# INFO:wecopttool.core:Solving pseudo-spectral control problem for realization number 0.
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [1.60e+00, 1.00e+00, 6.32e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [1.41e+00, 2.74e+00, 1.42e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [9.90e-01, 2.62e+00, 1.60e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [1.68e+00, 5.04e+00, 5.88e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [2.65e+00, 4.89e+00, 7.81e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [2.94e+00, 4.30e+00, 1.02e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [2.14e+00, 4.04e+00, 1.17e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.91e+00, 7.76e+00, 1.68e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [4.43e+00, 9.06e+00, 6.26e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [2.09e+01, 5.67e+01, 6.17e+05]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [6.40e+00, 1.46e+01, 3.56e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [2.91e+00, 8.59e+00, 3.45e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.20e+00, 8.33e+00, 1.08e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [4.17e+00, 1.23e+01, 1.34e+02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.97e+00, 1.07e+01, 6.11e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [4.10e+00, 1.06e+01, 1.63e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [5.46e+00, 1.57e+01, 2.93e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.91e+00, 1.17e+01, 1.04e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [4.35e+00, 1.31e+01, 4.22e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [4.24e+00, 1.28e+01, 4.00e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [4.06e+00, 1.25e+01, 2.33e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [4.79e+00, 1.63e+01, 1.06e+01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [4.28e+00, 1.38e+01, 1.63e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [4.19e+00, 1.35e+01, 1.16e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.86e+00, 1.29e+01, 4.57e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.92e+00, 1.33e+01, 3.51e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.94e+00, 1.35e+01, 3.17e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.95e+00, 1.35e+01, 2.06e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.97e+00, 1.35e+01, 1.40e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.99e+00, 1.36e+01, 9.75e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [4.00e+00, 1.37e+01, 6.76e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [4.00e+00, 1.38e+01, 4.57e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.99e+00, 1.41e+01, 3.04e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.93e+00, 1.46e+01, 2.21e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.95e+00, 1.57e+01, 3.06e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.70e+00, 1.57e+01, 1.17e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.85e+00, 1.64e+01, 2.63e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.77e+00, 1.62e+01, -8.96e-02]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.79e+00, 1.62e+01, -4.77e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.77e+00, 1.60e+01, -7.03e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.79e+00, 1.60e+01, -8.96e-01]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.82e+00, 1.60e+01, -1.05e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.81e+00, 1.58e+01, -1.07e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.82e+00, 1.60e+01, -1.11e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.83e+00, 1.61e+01, -1.12e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.82e+00, 1.63e+01, -1.14e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.81e+00, 1.65e+01, -1.15e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.79e+00, 1.68e+01, -1.16e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.76e+00, 1.69e+01, -1.17e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.69e+01, -1.17e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.68e+01, -1.17e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.68e+01, -1.18e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.68e+01, -1.18e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.68e+01, -1.18e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.68e+01, -1.18e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.68e+01, -1.18e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.68e+01, -1.18e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.68e+01, -1.18e+00]
# INFO:wecopttool.core:Scaled [max(x_wec), max(x_opt), obj_fun(x)]: [3.75e+00, 1.68e+01, -1.18e+00]
# INFO:wecopttool.core:Optimization terminated successfully    (Exit mode 0)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.1769356867322809
#             Iterations: 59
#             Function evaluations: 96
#             Gradient evaluations: 59

# %%
table = study.results_table(results)
table
# Out:
#       P      I  coupled  avg_power  objective  \
# 0  True  False    False     -1.165     -1.165
# 1  True  False     True     -1.171     -1.171
# 2  True   True    False     -1.177     -1.177
# 3  True   True     True     -1.177     -1.177
#
#                                                x_opt        case
# 0  [-6.662032157556805e-21, 0.0015505704035789335...           P
# 1  [-6.220980698037754e-20, 0.0015504442352441354...   P_coupled
# 2  [1.4264057239401216e-19, 0.0015520363136227982...          PI
# 3  [1.2459039109401822e-19, 0.0015520363873750302...  PI_coupled

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.patches import Polygon, Circle


def animate_foswec_m4e_sideview(
    wec_tdom_full,
    waves,
    interval=None,
    stride=2,
    repeat=True,
    figsize=(9, 4),
    xlim=None,
    zlim=None,
    slow_down_ani=1.0,
    n_wave_x=100,
    wave_color="royalblue",
    wave_alpha=0.95,
    body_alpha=0.9,
    show_waterline=True,
    show_time_text=True,
    show_wave_fill=False,
):
    """
    Lightweight side-view animation of the full FOSWEC M4E model with incident waves.

    Parameters
    ----------
    wec_tdom_full : xarray Dataset
        Time-domain output for one controller case.
    waves : WecOptTool waves object
        Wave definition used in the solve.
    interval : float or None
        Frame interval in ms. If None, computed from simulation dt and stride.
    stride : int
        Plot every `stride`-th frame to reduce animation size.
    repeat : bool
        Whether animation repeats.
    figsize : tuple
        Figure size.
    xlim, zlim : tuple or None
        Axes limits.
    slow_down_ani : float
        >1 slower, <1 faster.
    n_wave_x : int
        Number of x-points for the wave curve.
    """

    # -----------------------------
    # Geometry
    # -----------------------------
    flapThicknessBottom = 0.04
    flapThicknessTop = 0.1
    flapCenterDistanceApart = 1.44
    flapHeight = 0.58
    flapDraft = 0.59

    platformFrameLength = 1.44
    platformFrameThickness = 0.05
    platformFrameTopDepth = 0.53 + 0.1

    fullWidth = 1.63
    columnsRadius = 0.1
    columnsDraft = 0.53 + 0.1 + 0.4
    columnsXY = [flapCenterDistanceApart / 2, fullWidth / 2 - columnsRadius]

    daqLength = 0.72
    daqHeight = 0.2
    daqTopDepth = 0.53 + 0.1 + 0.05

    # -----------------------------
    # Time histories
    # -----------------------------
    time = np.asarray(wec_tdom_full["time"].values)[::stride]

    surge = np.asarray(
        wec_tdom_full["pos"].isel(realization=0, influenced_dof=0).values
    )[::stride]
    heave = np.asarray(
        wec_tdom_full["pos"].isel(realization=0, influenced_dof=1).values
    )[::stride]
    pitch = np.asarray(
        wec_tdom_full["pos"].isel(realization=0, influenced_dof=2).values
    )[::stride]
    flap1_pitch = np.asarray(
        wec_tdom_full["pos"].isel(realization=0, influenced_dof=5).values
    )[::stride]
    flap2_pitch = np.asarray(
        wec_tdom_full["pos"].isel(realization=0, influenced_dof=8).values
    )[::stride]

    if len(time) < 2:
        raise ValueError("Animation requires at least two time samples.")

    dt_sim = float(time[1] - time[0])
    if interval is None:
        interval = max(1, int(1000.0 * dt_sim * slow_down_ani))

    # -----------------------------
    # Helpers
    # -----------------------------
    def rot2(theta):
        c = np.cos(theta)
        s = np.sin(theta)
        return np.array([[c, -s],
                         [s,  c]])

    def transform_points(points_xz, theta, translation_xz):
        R = rot2(theta)
        return points_xz @ R.T + np.asarray(translation_xz)

    # -----------------------------
    # Local geometry
    # -----------------------------
    platform_local = np.array([
        [-platformFrameLength / 2, -platformFrameTopDepth - platformFrameThickness],
        [ platformFrameLength / 2, -platformFrameTopDepth - platformFrameThickness],
        [ platformFrameLength / 2, -platformFrameTopDepth],
        [-platformFrameLength / 2, -platformFrameTopDepth],
    ])

    daq_local = np.array([
        [-daqLength / 2, -daqTopDepth - daqHeight],
        [ daqLength / 2, -daqTopDepth - daqHeight],
        [ daqLength / 2, -daqTopDepth],
        [-daqLength / 2, -daqTopDepth],
    ])

    col_x_positions = [-columnsXY[0], columnsXY[0]]
    col_rects_local = []
    for xcol in col_x_positions:
        rect = np.array([
            [xcol - columnsRadius, -columnsDraft],
            [xcol + columnsRadius, -columnsDraft],
            [xcol + columnsRadius, 0.0],
            [xcol - columnsRadius, 0.0],
        ])
        col_rects_local.append(rect)

    flap_local = np.array([
        [-flapThicknessBottom / 2, 0.0],
        [ flapThicknessBottom / 2, 0.0],
        [ flapThicknessTop / 2, flapHeight],
        [-flapThicknessTop / 2, flapHeight],
    ])

    flap1_hinge_local = np.array([-flapCenterDistanceApart / 2, -flapDraft])
    flap2_hinge_local = np.array([ flapCenterDistanceApart / 2, -flapDraft])

    # -----------------------------
    # Limits
    # -----------------------------
    if xlim is None:
        xlim = (-2.3, 2.3)
    if zlim is None:
        zlim = (-1.45, 0.35)

    # -----------------------------
    # Incident wave field
    # -----------------------------
    spatial_x = np.linspace(xlim[0], xlim[1], n_wave_x)

    omega = np.asarray(waves.omega.values, dtype=float)
    wave_complex = np.squeeze(np.asarray(waves.values))

    if wave_complex.ndim != 1:
        raise ValueError(
            f"Expected squeezed wave amplitudes to be 1D over omega, got shape {wave_complex.shape}"
        )

    amp = np.abs(wave_complex)
    phase = np.angle(wave_complex)
    k = omega**2 / 9.81  # deep-water approximation

    wave_elevations = np.zeros((len(time), len(spatial_x)))
    for i, t in enumerate(time):
        wave_elevations[i, :] = np.sum(
            amp[:, None] * np.cos(
                omega[:, None] * t - k[:, None] * spatial_x[None, :] + phase[:, None]
            ),
            axis=0,
        )

    # -----------------------------
    # Figure
    # -----------------------------
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_aspect("equal")
    ax.set_xlim(*xlim)
    ax.set_ylim(*zlim)
    ax.set_xlabel("x [m]")
    ax.set_ylabel("z [m]")
    ax.set_title("FOSWEC M4E Side View")
    ax.grid(True, alpha=0.25)

    if show_waterline:
        ax.axhline(0.0, color="deepskyblue", linestyle="--", linewidth=1.0, alpha=0.7)

    wave_line, = ax.plot([], [], color=wave_color, lw=1.8, alpha=wave_alpha, zorder=1)

    platform_patch = Polygon(
        platform_local, closed=True, facecolor="0.45", edgecolor="k", alpha=body_alpha, zorder=5
    )
    daq_patch = Polygon(
        daq_local, closed=True, facecolor="tab:orange", edgecolor="k", alpha=body_alpha, zorder=6
    )

    column_patches = [
        Polygon(rect, closed=True, facecolor="tab:gray", edgecolor="k", alpha=0.85, zorder=4)
        for rect in col_rects_local
    ]

    flap1_patch = Polygon(
        flap_local + flap1_hinge_local, closed=True,
        facecolor="tab:red", edgecolor="k", alpha=body_alpha, zorder=7
    )
    flap2_patch = Polygon(
        flap_local + flap2_hinge_local, closed=True,
        facecolor="tab:green", edgecolor="k", alpha=body_alpha, zorder=7
    )

    ax.add_patch(platform_patch)
    ax.add_patch(daq_patch)
    for cp in column_patches:
        ax.add_patch(cp)
    ax.add_patch(flap1_patch)
    ax.add_patch(flap2_patch)

    hinge1_marker = Circle((flap1_hinge_local[0], flap1_hinge_local[1]), 0.015, color="k", zorder=8)
    hinge2_marker = Circle((flap2_hinge_local[0], flap2_hinge_local[1]), 0.015, color="k", zorder=8)
    ax.add_patch(hinge1_marker)
    ax.add_patch(hinge2_marker)

    time_text = None
    if show_time_text:
        time_text = ax.text(
            0.02, 0.97, "",
            transform=ax.transAxes,
            ha="left", va="top",
            fontsize=9,
            bbox=dict(facecolor="white", alpha=0.75, edgecolor="none"),
        )

    def update(i):
        x0 = surge[i]
        z0 = heave[i]
        th0 = pitch[i]
        th1 = flap1_pitch[i]
        th2 = flap2_pitch[i]

        wave_line.set_data(spatial_x, wave_elevations[i, :])

        platform_patch.set_xy(transform_points(platform_local, th0, [x0, z0]))
        daq_patch.set_xy(transform_points(daq_local, th0, [x0, z0]))

        for rect_local, patch in zip(col_rects_local, column_patches):
            patch.set_xy(transform_points(rect_local, th0, [x0, z0]))

        hinge1_global = transform_points(flap1_hinge_local.reshape(1, 2), th0, [x0, z0])[0]
        hinge2_global = transform_points(flap2_hinge_local.reshape(1, 2), th0, [x0, z0])[0]

        flap1_patch.set_xy(transform_points(flap_local, th0 + th1, hinge1_global))
        flap2_patch.set_xy(transform_points(flap_local, th0 + th2, hinge2_global))

        hinge1_marker.center = hinge1_global
        hinge2_marker.center = hinge2_global

        if show_time_text:
            time_text.set_text(
                f"t = {time[i]:.2f} s\n"
                f"surge = {x0:.2f} m, heave = {z0:.2f} m\n"
                f"pitch = {np.degrees(th0):.1f} deg"
            )

        artists = [
            wave_line,
            platform_patch,
            daq_patch,
            *column_patches,
            flap1_patch,
            flap2_patch,
            hinge1_marker,
            hinge2_marker,
        ]
        if show_time_text:
            artists.append(time_text)
        return artists

    anim = FuncAnimation(
        fig,
        update,
        frames=len(time),
        interval=interval,
        blit=False,
        repeat=repeat,
        repeat_delay=0,
    )

    plt.close(fig)
    return anim

# %%
import matplotlib as mpl
from IPython.display import HTML
mpl.rcParams["animation.embed_limit"] = 30
plt.rcParams["animation.html"] = "jshtml"


case_name = "PI_coupled"
case = results[case_name]

anim = animate_foswec_m4e_sideview(
    case["wec_tdom_full"],
    study.waves,
    stride=3,
    slow_down_ani=1.0,
    figsize=(8, 4),
    xlim=(-2.3, 2.3),
    zlim=(-1.45, 0.35),
    n_wave_x=80,
    show_wave_fill=False,
)

# %%
from IPython.display import HTML
plt.rcParams["animation.html"] = "jshtml"
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgad88697a411c415dbc848b1fbc89afe1">
#   <div class="anim-controls">
#     <input id="_anim_sliderad88697a411c415dbc848b1fbc89afe1" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animad88697a411c415dbc848b1fbc89afe1.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animad88697a411c415dbc848b1fbc89afe1.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animad88697a411c415dbc848b1fbc89afe1.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animad88697a411c415dbc848b1fbc89afe1.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animad88697a411c415dbc848b1fbc89afe1.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animad88697a411c415dbc848b1fbc89afe1.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animad88697a411c415dbc848b1fbc89afe1.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animad88697a411c415dbc848b1fbc89afe1.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animad88697a411c415dbc848b1fbc89afe1.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animad88697a411c415dbc848b1fbc89afe1.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectad88697a411c415dbc848b1fbc89afe1"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_ad88697a411c415dbc848b1fbc89afe1"
#              >
#       <label for="_anim_radio1_ad88697a411c415dbc848b1fbc89afe1">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_ad88697a411c415dbc848b1fbc89afe1"
#              checked>
#       <label for="_anim_radio2_ad88697a411c415dbc848b1fbc89afe1">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_ad88697a411c415dbc848b1fbc89afe1"
#              >
#       <label for="_anim_radio3_ad88697a411c415dbc848b1fbc89afe1">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgad88697a411c415dbc848b1fbc89afe1";
#     var slider_id = "_anim_sliderad88697a411c415dbc848b1fbc89afe1";
#     var loop_select_id = "_anim_loop_selectad88697a411c415dbc848b1fbc89afe1";
#     var frames = new Array(67);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjcsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvTLEjVAAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAZ6xJR

# %%
case["wec_tdom_full"]
# Out:
# <xarray.Dataset> Size: 159kB
# Dimensions:                 (realization: 1, time: 200, influenced_dof: 9,
#                              reduced_influenced_dof: 5, type: 5,
#                              wave_direction: 1)
# Coordinates:
#   * realization             (realization) int32 4B 0
#   * time                    (time) float64 2kB 0.0 0.025 0.05 ... 4.95 4.975
#   * influenced_dof          (influenced_dof) <U5 180B 'DOF_0' ... 'DOF_8'
#   * reduced_influenced_dof  (reduced_influenced_dof) <U5 100B 'DOF_0' ... 'DO...
#   * type                    (type) object 40B 'intrinsic_impedance' ... 'f_PTO'
#   * wave_direction          (wave_direction) float64 8B 0.0
#     omega                   float64 8B 12.57
#     freq                    float64 8B 2.0
#     period                  float64 8B 0.5
# Data variables:
#     pos                     (realization, influenced_dof, time) float64 14kB ...
#     vel                     (realization, influenced_dof, time) float64 14kB ...
#     acc                     (realization, influenced_dof, time) float64 14kB ...
#     force                   (realization, reduced_influenced_dof, type, time) float64 40kB ...
#     force_full              (realization, influenced_dof, type, time) float64 72kB ...
#     wave_elev               (realization, wave_direction, time) float64 2kB 0...
# Attributes:
#     time_created_utc:  2026-07-27 20:45:14.541958
